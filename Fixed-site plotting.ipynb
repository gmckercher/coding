# %%
import pandas as pd
from netCDF4 import Dataset, num2date
import matplotlib.pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'svg'
filename = '/Users/TTUatmo/Dropbox/TTU/Thesis Research/Data and Records/Text Files from Station/Grant_0416_0417.txt'
data = pd.read_csv(filename,sep='\t',header=1,skiprows=[2,3])

# %%
time = pd.to_datetime(data.TIMESTAMP)
time.shape
#timestamp = num2date(time,time_var.units).squeeze()
# Out:
# (17107,)

# %%
from datetime import datetime
print datetime.now()
# Out:
# 2015-08-20 16:04:08.852367

# %%
time
# Out:
# 0    2015-04-05 17:53:00
# 1    2015-04-05 17:54:00
# 2    2015-04-05 17:55:00
# 3    2015-04-05 17:56:00
# 4    2015-04-05 17:57:00
# 5    2015-04-05 17:58:00
# 6    2015-04-05 17:59:00
# 7    2015-04-05 18:00:00
# 8    2015-04-05 18:01:00
# 9    2015-04-05 18:02:00
# 10   2015-04-05 18:03:00
# 11   2015-04-05 18:04:00
# 12   2015-04-05 18:05:00
# 13   2015-04-05 18:06:00
# 14   2015-04-05 18:07:00
# ...
# 17092   2015-04-17 15:00:00
# 17093   2015-04-17 15:01:00
# 17094   2015-04-17 15:02:00
# 17095   2015-04-17 15:03:00
# 17096   2015-04-17 15:04:00
# 17097   2015-04-17 15:05:00
# 17098   2015-04-17 15:06:00
# 17099   2015-04-17 15:07:00
# 17100   2015-04-17 15:08:00
# 17101   2015-04-17 15:09:00
# 17102   2015-04-17 15:10:00
# 17103   2015-04-17 15:11:00
# 17104   2015-04-17 15:12:00
# 17105   2015-04-17 15:13:00
# 17106   2015-04-17 15:14:00
# Name: TIMESTAMP, Length: 17107, dtype: datetime64[ns]

# %%
TC = data.AirTC
TC.shape
# Out:
# (17107,)

# %%
fig,ax = plt.subplots(1,1,figsize=(12,6))
ax.plot(time,TC,'r-', linewidth = '1')
# from matplotlib.dates import DateFormatter,DayLocator,HourLocator
# ax.xaxis.set_major_locator(DayLocator())
# ax.xaxis.set_minor_locator(HourLocator())

# ax.xaxis.set_major_formatter(DateFormatter('%d'))
# #ax.xaxis.set_minor_formatter(DateFormatter('%Hz'))
