# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import csv
from pandas import DataFrame,date_range
import matplotlib.dates as mdates

Oct14 = pd.read_csv('Oct14_combo.csv')
Nov2 = pd.read_csv('Nov2_combo.csv')
Nov3 = pd.read_csv('Nov3_combo.csv')
Nov4 = pd.read_csv('Nov4_combo.csv')
Nov10 = pd.read_csv('Nov10_combo.csv')

# %%
#get_datetime = lambda s: datetime.datetime.strptime(s, "%H:%M:%S %p")
Oct14time = Oct14['sck_fs_time']
Oct14x = [datetime.datetime.strptime(s, "%Y-%m-%d %H:%M:%S") for s in Oct14time]
Nov2time = Nov2['sck_adj_time']
Nov2x = [datetime.datetime.strptime(s, "%Y-%m-%d %H:%M:%S") for s in Nov2time]
Nov3time = Nov3['sckfs_time']
Nov3x = [datetime.datetime.strptime(s, "%Y-%m-%d %H:%M:%S") for s in Nov3time]
Nov4time = Nov4['sck_time']
Nov4x = [datetime.datetime.strptime(s, "%Y-%m-%d %H:%M:%S") for s in Nov4time]
Nov10time = Nov10['sck_fs_time']
Nov10x = [datetime.datetime.strptime(s, "%Y-%m-%d %H:%M:%S") for s in Nov10time]
xfmt = mdates.DateFormatter('%H:%M')

# %%
def subplot_sckgps_Fall(variablename,title,ylabel,ymin,ymax):
    ''' plots a specified variable for the five days in the Fall in subplots'''
    fig = plt.figure(figsize=(14,12))
    ax1 = fig.add_subplot(511)
    ax1.xaxis.set_major_formatter(xfmt)
    ax1.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
    ax1.plot(Oct14x,Oct14[variablename],label='Oct14',linewidth=2)
    ax1.set_title(title)
    ax1.set_ylim(ymin,ymax)
    ax1.set_ylabel(ylabel)
    ax1.legend(loc='upper left')

    ax2 = fig.add_subplot(512)
    ax2.xaxis.set_major_formatter(xfmt)
    ax2.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
    ax2.plot(Nov2x,Nov2[variablename],label='Nov2',c='r',linewidth=2)
    ax2.set_ylim(ymin,ymax)
    ax2.set_ylabel(ylabel)
    ax2.legend(loc='upper left')

    ax3 = fig.add_subplot(513)
    ax3.xaxis.set_major_formatter(xfmt)
    ax3.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
    ax3.plot(Nov3x,Nov3[variablename],label='Nov3',c='g',linewidth=2)
    ax3.set_ylim(ymin,ymax)
    ax3.set_ylabel(ylabel)
    ax3.legend(loc='upper left')

    ax4 = fig.add_subplot(514)
    ax4.xaxis.set_major_formatter(xfmt)
    ax4.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
    ax4.plot(Nov4x,Nov4[variablename],label='Nov4',c='purple',linewidth=2)
    ax4.set_ylim(ymin,ymax)
    ax4.set_ylabel(ylabel)
    ax4.legend(loc='upper left')

    ax5 = fig.add_subplot(515)
    ax5.xaxis_date()
    ax5.xaxis.set_major_formatter(xfmt)
    ax5.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
    ax5.plot(Nov10x,Nov10[variablename],label='Nov10',c='orange',linewidth=2)
    ax5.set_ylim(ymin,ymax)
    ax5.set_ylabel(ylabel)
    ax5.legend(loc='upper left')

# %%
def subplot_fs_Fall(variablename,title,ylabel,ymin,ymax):
    ''' plots a specified variable for the five days in the Fall in subplots'''
    fig = plt.figure(figsize=(14,10))
    ax1 = fig.add_subplot(411)
    ax1.xaxis.set_major_formatter(xfmt)
    ax1.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
    ax1.plot(Oct14x,Oct14[variablename],label='Oct14',linewidth=2)
    ax1.set_title(title)
    ax1.set_ylim(ymin,ymax)
    ax1.set_ylabel(ylabel)
    ax1.legend(loc='upper left')

    ax3 = fig.add_subplot(412)
    ax3.xaxis.set_major_formatter(xfmt)
    ax3.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
    ax3.plot(Nov3x,Nov3[variablename],label='Nov3',c='g',linewidth=2)
    ax3.set_ylim(ymin,ymax)
    ax3.set_ylabel(ylabel)
    ax3.legend(loc='upper left')

    ax4 = fig.add_subplot(413)
    ax4.xaxis.set_major_formatter(xfmt)
    ax4.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
    ax4.plot(Nov4x,Nov4[variablename],label='Nov4',c='purple',linewidth=2)
    ax4.set_ylim(ymin,ymax)
    ax4.set_ylabel(ylabel)
    ax4.legend(loc='upper left')

    ax5 = fig.add_subplot(414)
    ax5.xaxis_date()
    ax5.xaxis.set_major_formatter(xfmt)
    ax5.xaxis.set_major_locator(mdates.MinuteLocator(interval=2))
    ax5.plot(Nov10x,Nov10[variablename],label='Nov10',c='orange',linewidth=2)
    ax5.set_ylim(ymin,ymax)
    ax5.set_ylabel(ylabel)
    ax5.legend(loc='upper left')

# %%
subplot_sckgps_Fall('sck_COppm','SCK Carbon Monoxide (ppm)','SCK CO_ppm',0,2000)

# %%
subplot_sckgps_Fall('sck_NO2ppm','SCK Carbon Monoxide (ppm)','SCK CO_ppm',0,45)

# %%
subplot_fs_Fall('fs_COppm','FS Carbon Monoxide (ppm)','CO_ppm',0,3)

# %%
subplot_fs_Fall('fs_SolarW','FS Solar','Solar',0,400)

# %%
fig = plt.figure(figsize=(14,4))
x14 = np.linspace(0,500,Oct14['fs_TempF'].shape[0])
x2 = np.linspace(0,500,np.zeros_like(Nov2['Altitude (m)']).shape[0])
x3 = np.linspace(0,500,Nov3['fs_TempF'].shape[0])
x4 = np.linspace(0,500,Nov4['fs_TempF'].shape[0])
x10 = np.linspace(0,500,Nov10['fs_TempF'].shape[0])
plt.title('FS Temp (F)')
plt.ylabel(' Temp (F)')
plt.plot(x14,Oct14['fs_TempF'],label='Oct14',linewidth=2)
plt.plot(x3,Nov3['fs_TempF'],label='Nov3',c='g',linewidth=2)
plt.plot(x4,Nov4['fs_TempF'],label='Nov4',c='purple',linewidth=2)
plt.plot(x10,Nov10['fs_TempF'],label='Nov10',c='orange',linewidth=2)
plt.legend(loc='center right',bbox_to_anchor=(1.12, 0.5))

# %%
fig = plt.figure(figsize=(13,5))
x14 = np.linspace(0,500,Oct14['fs_TempF'].shape[0])
x2 = np.linspace(0,500,np.zeros_like(Nov2['Altitude (m)']).shape[0])
x3 = np.linspace(0,500,Nov3['fs_TempF'].shape[0])
x4 = np.linspace(0,500,Nov4['fs_TempF'].shape[0])
x10 = np.linspace(0,500,Nov10['fs_TempF'].shape[0])
#plt.title('FS RH (%)')
plt.ylabel('Relative Humidity (%)', fontsize = 18)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.plot(x14,Oct14['fs_RH%'],label='Oct14',linewidth=2)
plt.plot(x3,Nov3['fs_RH%'],label='Nov3',c='g',linewidth=2)
plt.plot(x4,Nov4['fs_RH%'],label='Nov4',c='purple',linewidth=2)
plt.plot(x10,Nov10['fs_RH%'],label='Nov10',c='orange',linewidth=2)
plt.legend(loc='center right',bbox_to_anchor=(1.145, 0.5),fontsize=14)

# %%
fig = plt.figure(figsize=(14,4))
x14 = np.linspace(0,500,Oct14['fs_TempF'].shape[0])
x2 = np.linspace(0,500,np.zeros_like(Nov2['Altitude (m)']).shape[0])
x3 = np.linspace(0,500,Nov3['fs_TempF'].shape[0])
x4 = np.linspace(0,500,Nov4['fs_TempF'].shape[0])
x10 = np.linspace(0,500,Nov10['fs_TempF'].shape[0])
plt.title('FS SOLAR (W/m^2)')
plt.ylabel('SOLAR (W/m^2)')
plt.plot(x14,Oct14['fs_SolarW'],label='Oct14',linewidth=2)
plt.plot(x3,Nov3['fs_SolarW'],label='Nov3',c='g',linewidth=2)
plt.plot(x4,Nov4['fs_SolarW'],label='Nov4',c='purple',linewidth=2)
plt.plot(x10,Nov10['fs_SolarW'],label='Nov10',c='orange',linewidth=2)
plt.legend(loc='center right',bbox_to_anchor=(1.12, 0.5))

# %%
fig = plt.figure(figsize=(14,4))
x14 = np.linspace(0,500,Oct14['fs_TempF'].shape[0])
x2 = np.linspace(0,500,np.zeros_like(Nov2['Altitude (m)']).shape[0])
x3 = np.linspace(0,500,Nov3['fs_TempF'].shape[0])
x4 = np.linspace(0,500,Nov4['fs_TempF'].shape[0])
x10 = np.linspace(0,500,Nov10['fs_TempF'].shape[0])
plt.title('FS WIND (mph)')
plt.ylabel('WIND (mph)')
plt.plot(x14,Oct14['fs_WSmph'],label='Oct14',linewidth=1)
plt.plot(x3,Nov3['fs_WSmph'],label='Nov3',c='g',linewidth=1)
plt.plot(x4,Nov4['fs_WSmph'],label='Nov4',c='purple',linewidth=1)
plt.plot(x10,Nov10['fs_WSmph'],label='Nov10',c='orange',linewidth=1)
plt.legend(loc='center right',bbox_to_anchor=(1.12, 0.5))

# %%
fig = plt.figure(figsize=(14,4))
x14 = np.linspace(0,500,Oct14['fs_TempF'].shape[0])
x2 = np.linspace(0,500,np.zeros_like(Nov2['Altitude (m)']).shape[0])
x3 = np.linspace(0,500,Nov3['fs_TempF'].shape[0])
x4 = np.linspace(0,500,Nov4['fs_TempF'].shape[0])
x10 = np.linspace(0,500,Nov10['fs_TempF'].shape[0])
plt.title('FS WIND (deg)')
plt.ylabel('WIND (deg)')
plt.plot(x14,Oct14['fs_WDdeg'],label='Oct14',linewidth=1)
plt.plot(x3,Nov3['fs_WDdeg'],label='Nov3',c='g',linewidth=1)
plt.plot(x4,Nov4['fs_WDdeg'],label='Nov4',c='purple',linewidth=1)
plt.plot(x10,Nov10['fs_WDdeg'],label='Nov10',c='orange',linewidth=1)
plt.legend(loc='center right',bbox_to_anchor=(1.12, 0.5))

# %%
from pylab import plot, show, savefig, xlim, figure, \
                hold, ylim, legend, boxplot, setp, axes
def boxplot_days(data1,data2,data3,data4,title,ylabel):
    fig = figure(figsize=[12,8])
    ax = axes()
    ax.set_title(title,fontsize=14)
    ax.set_ylabel(ylabel,fontsize=18)
    ax.boxplot(data1, positions=[1], widths=0.3)
    ax.boxplot(data2, positions=[2], widths=0.3)
    ax.boxplot(data3, positions=[3], widths=0.3)
    ax.boxplot(data4, positions=[4], widths=0.3)
    xlim(0.5,4.5)
    ylim(-0.5,20)
    ax.set_xticks([1,2,3,4])
    #ax.set_yticklabels([5,10,15,20,25,30,35,40,45],fontsize=14)
    ax.set_xticklabels(['Oct14','Nov3','Nov4','Nov10'],fontsize=16)

# %%
boxplot_days(Oct14['fs_WSmph'],Nov3['fs_WSmph'],Nov4['fs_WSmph'],Nov10['fs_WSmph'],'','Wind Speed (mph)')

# %%
print Oct14['fs_TempF'].mean()
print Nov3['fs_TempF'].mean()
print Nov4['fs_TempF'].mean()
print Nov10['fs_TempF'].mean()
# Out:
# 88.9647097967
# 78.0099118236
# 77.7589387755
# 75.2503647059

# %%
print Oct14['fs_RH%'].mean()
print Nov3['fs_RH%'].mean()
print Nov4['fs_RH%'].mean()
print Nov10['fs_RH%'].mean()
# Out:
# 23.4568391867
# 27.7720240481
# 42.7820408163
# 33.4638627451

# %%
print Oct14['fs_SolarW'].mean()
print Nov3['fs_SolarW'].mean()
print Nov4['fs_SolarW'].mean()
print Nov10['fs_SolarW'].mean()
# Out:
# 294.646170055
# 63.9090731463
# 97.4110367347
# 74.8244621569

# %%
print Oct14['fs_WDdeg'].mean()
print Nov3['fs_WDdeg'].mean()
print Nov4['fs_WDdeg'].mean()
print Nov10['fs_WDdeg'].mean()
# Out:
# 181.633049908
# 162.014028056
# 165.068367347
# 189.327254902

# %%
print Oct14['sck_COppm'].mean()
print Nov3['sck_COppm'].mean()
print Nov4['sck_COppm'].mean()
print Nov10['sck_COppm'].mean()
# Out:
# 884.767430684
# 827.171462926
# 1079.96714286
# 1049.85027451

# %%
print Oct14['sck_NO2ppm'].mean()
print Nov3['sck_NO2ppm'].mean()
print Nov4['sck_NO2ppm'].mean()
print Nov10['sck_NO2ppm'].mean()
# Out:
# 16.2339001848
# 26.3576753507
# 21.9968367347
# 25.0054313725
